# %%
from diffusers import AutoPipelineForText2Image
import torch

# Load the stable diffusion turbo pipeline

pipe = AutoPipelineForText2Image.from_pretrained("stabilityai/sdxl-turbo", torch_dtype=torch.float16, variant="fp16")
pipe.to("cuda")

prompt = "Low ploy figurine of a fox on a blank background"

image = pipe(prompt=prompt, num_inference_steps=1, guidance_scale=0.0).images[0]
# Out:
# Loading pipeline components...: 100%|██████████| 7/7 [00:00<00:00, 10.76it/s]
# 100%|██████████| 1/1 [00:00<00:00, 16.37it/s]

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Convert the generated image to a format that can be displayed
image = image.convert("RGB")

# Display the image using matplotlib
plt.imshow(image)
plt.axis('off')  # Hide the axis
plt.show()
